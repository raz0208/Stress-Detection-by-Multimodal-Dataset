# %% [markdown]
# # **StressID Dataset Analysis**
# ### EDA on demographics and self_assessment merged dataset

# %%
# # Install packages
# %pip install numpy pandas seaborn matplotlib plotly -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# import required libraries
import numpy as np
import pandas as pd
import matplotlib as mpl
import seaborn as sns

# %%
# -- read and load demographics.csv --
demographics = pd.read_csv("data/demographics.csv", sep = ";")
demographics

# -- read and load self_assessments.csv --
# Out:
#    Subject   Age Gender
# 0     8g4y  24.0      M
# 1     qw5t  25.0      F
# 2     h8r2  26.0      M
# 3     2z7d  24.0      M
# 4     j9h8  26.0      M
# ..     ...   ...    ...
# 60    kycf  24.0      M
# 61    k67g  27.0      M
# 62    chdf  30.0      M
# 63    bfl5  28.0      M
# 64    dmbd  25.0      F
#
# [65 rows x 3 columns]
