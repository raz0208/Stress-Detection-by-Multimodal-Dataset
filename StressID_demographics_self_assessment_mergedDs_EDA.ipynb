# %% [markdown]
# ### **EDA on demograapphics and self assessment merged dataset**
# EDA on `demographics` and `self_assessment`, and `labels_all` merged dataset

# %%
# # Install packages
# %pip install numpy pandas seaborn matplotlib plotly -q

# %%
# import required libraries
import numpy as numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read and load dataset
demographics = pd.read_csv('data/demographics.csv', sep=';')
self_assessments = pd.read_csv('data/self_assessments.csv', sep=';')
labels_all = pd.read_csv('data/labels_all.csv', sep=',', header=0)

print("Demographics datset review:")
print(demographics.head())

print("==" *50)
print("Self Assessments dataset review:")
print(self_assessments.head())

print("==" *50)
print("labels dataset review:")
print(labels_all.head())
# Out:
# Demographics datset review:
#   Subject   Age Gender
# 0    8g4y  24.0      M
# 1    qw5t  25.0      F
# 2    h8r2  26.0      M
# 3    2z7d  24.0      M
# 4    j9h8  26.0      M
# ...
# Self Assessments dataset review:
#                Tasks hh2e wfsl 37ir hvpa ql3b r0a3 qx2o wssm ctzy  ... y8c3  \
# 0    Breathing_relax    6    6    9    9   10   10    9    8    9  ...    9
# 1   Breathing_stress    5    4    2    1    1    0    2    0    0  ...    1
# 2  Breathing_valence  NaN    8    5    7    5    8    8    6    7  ...    5
# 3  Breathing_arousal  NaN    3    3    8    2    1    2    1    7  ...    7
# 4       Video1_relax    8    6    3    7   10   10    9    5    4  ...    8
#
#   g7r2 f6q3 e5p4 d4n6 c3m7 b2l8 a1k9 t6v9 b9w0
# 0    8    9   10    5    4    8    7    5    8
# 1    0    1    3    2    6    1    5    5    2
# 2    7    7    8    5    8    7    6    6    7
# 3    5    1    3    4    7    8    8    3    8
# 4    8    9    8    2    2    2    7    7    5
#
# ...

# %%
self_assessments.rename(columns = {'Tasks':'Subject'}, inplace = True)
self_assessments_transform = self_assessments.set_index('Subject').transpose()
self_assessments_transform.head()
# Out:
# Subject Breathing_relax Breathing_stress Breathing_valence Breathing_arousal  \
# hh2e                  6                5               NaN               NaN
# wfsl                  6                4                 8                 3
# 37ir                  9                2                 5                 3
# hvpa                  9                1                 7                 8
# ql3b                 10                1                 5                 2
#
# Subject Video1_relax Video1_stress Video1_valence Video1_arousal Video2_relax  \
# hh2e               8             2            NaN            NaN            7
# wfsl               6             3              7              2            4
# 37ir               3             3              8              8            5
# hvpa               7             1              7              7            7
# ql3b              10             0              8              4            2
#
# ...
