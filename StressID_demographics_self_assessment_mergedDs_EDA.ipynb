# %% [markdown]
# # **StressID Dataset Analysis**
# ### EDA on demographics and self_assessment merged dataset

# %%
# # Install packages
# %pip install numpy pandas seaborn matplotlib plotly -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# import required libraries
import numpy as np
import pandas as pd
import matplotlib as mpl
import seaborn as sns

# %%
# -- read and load demographics.csv dataset --
demographics = pd.read_csv("data/demographics.csv", sep = ";", header = 0)

# read and load self_assessments.csv dataset --
self_assessments = pd.read_csv("data/self_assessments.csv", sep = ";", header = 0)

demographics, self_assessments
# Out:
# (   Subject   Age Gender
#  0     8g4y  24.0      M
#  1     qw5t  25.0      F
#  2     h8r2  26.0      M
#  3     2z7d  24.0      M
#  4     j9h8  26.0      M
#  ..     ...   ...    ...
#  60    kycf  24.0      M
#  61    k67g  27.0      M
#  62    chdf  30.0      M
#  63    bfl5  28.0      M
#  64    dmbd  25.0      F
#
#  [65 rows x 3 columns],
#                  Tasks       hh2e       wfsl      37ir     hvpa      ql3b  \
#  0     Breathing_relax          6          6         9        9        10
#  1    Breathing_stress          5          4         2        1         1
#  2   Breathing_valence        NaN          8         5        7         5
#  3   Breathing_arousal        NaN          3         3        8         2
#  4        Video1_relax          8          6         3        7        10
#  5       Video1_stress          2          3         3        1         0
#  6      Video1_valence        NaN          7         8        7         8
#  7      Video1_arousal        NaN          2         8        7         4
#  8        Video2_relax          7          4         5        7         2
#  9       Video2_stress          3          7         4        1         9
#  10     Video2_valence        NaN          4         5        7         3
#  11     Video2_arousal        NaN          2         8        6         3
#  12    Counting1_relax          6          1         3        6         4
#  13   Counting1_stress          5          9         4        3         2
#  14  Counting1_valence        NaN          2         4        7         6
#  15  Counting1_arousal        NaN          8         8        7         6
#  16    Counting2_relax          3          0         2        5         4
#  17   Counting2_stress          7         10         6        4         7
#  18  Counting2_valence        NaN          1         3        7         6
#  19  Counting2_arousal        NaN          9         9        8         6
#  20       Stroop_relax          6          4         1        5         1
#  21      Stroop_stress          6          7         7        3         8
#  22     Stroop_valence        NaN          4         2        7         5
#  23     Stroop_arousal        NaN          7         9        8         9
#  24     Speaking_relax          6          5         1        6         0
#  25    Speaking_stress          6          4         8        3         8
#  26   Speaking_valence        NaN          5         2        7         5
#  27   Speaking_arousal        NaN          5         8        8        10
#  28         Math_relax          5          2         6        5         1
#  29        Math_stress          6          6         3        4         7
#  30       Math_valence        NaN          3         6        7         7
#  31       Math_arousal        NaN          6         8        7         9
#  32      Reading_relax          8          3         3        7         0
#  33     Reading_stress          4          5         7        6         9
#  34    Reading_valence        NaN          5         3        5         6
#  35    Reading_arousal        NaN          6         7        8        10
#  36    Counting3_relax          5          3         5        5         1
#  37   Counting3_stress          7          7         6        3         9
#  38  Counting3_valence        NaN          3         5        7         6
#  39  Counting3_arousal        NaN          6         8        8        10
#  40        Relax_relax          6        NaN         7        6        10
#  41       Relax_stress          6        NaN         1        2         0
#  42      Relax_valence        NaN        NaN         7        6         8
#  43      Relax_arousal        NaN        NaN         6        5         8
#  44     Most_stressful  Counting2  Counting2  Speaking  Reading  Speaking
#
#           r0a3      qx2o      wssm  ctzy  ...       y8c3       g7r2    f6q3  \
#  0          10         9         8     9  ...          9          8       9
#  1           0         2         0     0  ...          1          0       1
#  2           8         8         6     7  ...          5          7       7
#  3           1         2         1     7  ...          7          5       1
#  4          10         9         5     4  ...          8          8       9
#  5           6         1         3     6  ...          0          0       0
#  6           9         9         5     4  ...          6          8       8
#  7           9         2         4     7  ...          7          6       1
#  8           7         9         7     4  ...          8          7       9
#  9           5         2         2     6  ...          0          1       0
#  10          8         9         5     5  ...          6          5       8
#  11          8         2         2     5  ...          7          6       1
#  12          7         7         5     7  ...          8          3      10
#  13          5         5         6     6  ...          0          5       1
#  14          5         5         4     7  ...          6          6       5
#  15          3         5         7     9  ...          6          8       1
#  16          3         4         2     4  ...          6          1       9
#  17          7         7         6     6  ...          3          5       1
#  18          5         5         2     6  ...          5          5       5
#  19          2         6         7     9  ...          6          9       1
#  20          2         7         5     2  ...          8          0       6
#  21          6         2         4     7  ...          1          7       2
#  22          5         7         5    10  ...          6          3       5
#  23          3         2         6    10  ...          5          6       3
#  24          9         3         3     4  ...          7          4       8
#  25          2         7         7     7  ...          1          3       1
#  26          9         2         2     9  ...          5          5       5
#  27          7         8         6     9  ...          6          7       2
#  28          5         6        10     2  ...          7          6       5
#  29          6         6         1     8  ...          3          1       3
#  30          5         5         9     9  ...          6          5       5
#  31          3         6        10    10  ...          5          5       3
#  32          5         8         6     5  ...          8          7       8
#  33          6         2         2     6  ...          2          0       3
#  34          6         7         5     4  ...          6          5       4
#  35          3         3         8     7  ...          5          3       3
#  36          2         3         4     5  ...          7          2       8
#  37          8         6         4     6  ...          2          3       3
#  38          3         5         5     9  ...          6          4       5
#  39          6         6         6     9  ...          5          4       3
#  40         10         4         7     9  ...          9          8       9
#  41          1         5         0     1  ...          0          0       1
#  42          6         5         7     5  ...          6          5       8
#  43          2         3         0     1  ...          4          2       1
#  44  Counting3  Speaking  Speaking  Math  ...  Counting2  Counting3  Stroop
#
#           e5p4       d4n6    c3m7       b2l8       a1k9       t6v9       b9w0
#  0          10          5       4          8          7          5          8
#  1           3          2       6          1          5          5          2
#  2           8          5       8          7          6          6          7
#  3           3          4       7          8          8          3          8
#  4           8          2       2          2          7          7          5
#  5           3          0       7          1          5          2          2
#  6           9          7       8          7          7          7          5
#  7           3          4       8          8          8          6          7
#  8           9          3       7          4          7          6          4
#  9           3          7       4          5          4          3          3
#  10          8          5       7          6          7          4          5
#  11          4          7       7          7          8          7          7
#  12          8          1       2          2          4          2          3
#  13          2          8       9          7          8          7          4
#  14          8          5       7          5          5          3          5
#  15          5          8       7          6          7         10          9
#  16          9          7       2          1          2          2          1
#  17          2          5       8          9          8          4          6
#  18          9          5       7          3          3          3          3
#  19          5          6       7          4          6          8          9
#  20          9          3       4          2          2          0          3
#  21          2          6       7          8          8          5          6
#  22          8          5       8          6          5          5          4
#  23          4          4       8          7          7          7          9
#  24          7          4       1          6          3          3          2
#  25          2          7       9          7          7          6          7
#  26          8          5       6          8          7          5          4
#  27          4          4       7          7          7          7          9
#  28          7          3       2          4          3          2          3
#  29          2          8       8          6          8          7          6
#  30          7          5       6          4          5          4          5
#  31          5          6       6          6          6          7          9
#  32          8          4       2          4          4          3          2
#  33          2          6       7          5          7          5          6
#  34          8          5       6          6          7          5          5
#  35          4          4       6          6          7          6          5
#  36          7          4       2          4          7          7          1
#  37          2          5       7          7          6          1          7
#  38          8          5       6          7          7          7          5
#  39          5          6       5          6          7          8          8
#  40          8          5       7          6          8          3          2
#  41          2          3       5          5          3          3          5
#  42          7          5       6          7          8          5          5
#  43          3          3       7          6          5          0          4
#  44  Counting2  Counting1  Stroop  Counting2  Counting2  Counting2  Counting2
#
#  [45 rows x 66 columns])

# %%
self_assessments_transform = self_assessments.T
self_assessments_transform.index.name = "Subject"
self_assessments_transform
# Out:
#                       0                 1                  2   \
# Subject
# Tasks    Breathing_relax  Breathing_stress  Breathing_valence
# hh2e                   6                 5                NaN
# wfsl                   6                 4                  8
# 37ir                   9                 2                  5
# hvpa                   9                 1                  7
# ...                  ...               ...                ...
# c3m7                   4                 6                  8
# b2l8                   8                 1                  7
# a1k9                   7                 5                  6
# t6v9                   5                 5                  6
# b9w0                   8                 2                  7
#
#                         3             4              5               6   \
# Subject
# Tasks    Breathing_arousal  Video1_relax  Video1_stress  Video1_valence
# hh2e                   NaN             8              2             NaN
# wfsl                     3             6              3               7
# 37ir                     3             3              3               8
# hvpa                     8             7              1               7
# ...                    ...           ...            ...             ...
# c3m7                     7             2              7               8
# b2l8                     8             2              1               7
# a1k9                     8             7              5               7
# t6v9                     3             7              2               7
# b9w0                     8             5              2               5
#
#                      7             8              9   ...               35  \
# Subject                                               ...
# Tasks    Video1_arousal  Video2_relax  Video2_stress  ...  Reading_arousal
# hh2e                NaN             7              3  ...              NaN
# wfsl                  2             4              7  ...                6
# 37ir                  8             5              4  ...                7
# hvpa                  7             7              1  ...                8
# ...                 ...           ...            ...  ...              ...
# c3m7                  8             7              4  ...                6
# b2l8                  8             4              5  ...                6
# a1k9                  8             7              4  ...                7
# t6v9                  6             6              3  ...                6
# b9w0                  7             4              3  ...                5
#
#                       36                37                 38  \
# Subject
# Tasks    Counting3_relax  Counting3_stress  Counting3_valence
# hh2e                   5                 7                NaN
# wfsl                   3                 7                  3
# 37ir                   5                 6                  5
# hvpa                   5                 3                  7
# ...                  ...               ...                ...
# c3m7                   2                 7                  6
# b2l8                   4                 7                  7
# a1k9                   7                 6                  7
# t6v9                   7                 1                  7
# b9w0                   1                 7                  5
#
#                         39           40            41             42  \
# Subject
# Tasks    Counting3_arousal  Relax_relax  Relax_stress  Relax_valence
# hh2e                   NaN            6             6            NaN
# wfsl                     6          NaN           NaN            NaN
# 37ir                     8            7             1              7
# hvpa                     8            6             2              6
# ...                    ...          ...           ...            ...
# c3m7                     5            7             5              6
# b2l8                     6            6             5              7
# a1k9                     7            8             3              8
# t6v9                     8            3             3              5
# b9w0                     8            2             5              5
#
#                     43              44
# Subject
# Tasks    Relax_arousal  Most_stressful
# hh2e               NaN       Counting2
# wfsl               NaN       Counting2
# 37ir                 6        Speaking
# hvpa                 5         Reading
# ...                ...             ...
# c3m7                 7          Stroop
# b2l8                 6       Counting2
# a1k9                 5       Counting2
# t6v9                 0       Counting2
# b9w0                 4       Counting2
#
# [66 rows x 45 columns]
