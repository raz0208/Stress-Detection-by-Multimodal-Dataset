# %% [markdown]
# # **StressID Dataset Analysis**
# ### EDA on demographics and self_assessment merged dataset

# %%
# Install packages
# !pip install numpy pandas seaborn matplotlib plotly openpyxl -q

# %% [markdown]
# # import required libraried
# import numpy as pd
# import
