# %% [markdown]
# # **StressID Dataset Analysis**
# ### EDA on demographics and self_assessment merged dataset

# %%
# # Install packages
# %pip install numpy pandas seaborn matplotlib plotly -q

# %%
# import required libraries
import numpy as np
import pandas as pd
import matplotlib as mpl
import seaborn as sns

# %%
# -- read and load demographics.csv dataset --
demographics = pd.read_csv("data/demographics.csv", sep = ";", header = 0)

# read and load self_assessments.csv dataset --
self_assessments = pd.read_csv("data/self_assessments.csv", sep = ";", header = 0)

demographics, self_assessments
# Out:
# (   Subject   Age Gender
#  0     8g4y  24.0      M
#  1     qw5t  25.0      F
#  2     h8r2  26.0      M
#  3     2z7d  24.0      M
#  4     j9h8  26.0      M
#  ..     ...   ...    ...
#  60    kycf  24.0      M
#  61    k67g  27.0      M
#  62    chdf  30.0      M
#  63    bfl5  28.0      M
#  64    dmbd  25.0      F
#
#  [65 rows x 3 columns],
#                  Tasks       hh2e       wfsl      37ir     hvpa      ql3b  \
#  0     Breathing_relax          6          6         9        9        10
#  1    Breathing_stress          5          4         2        1         1
#  2   Breathing_valence        NaN          8         5        7         5
#  3   Breathing_arousal        NaN          3         3        8         2
#  4        Video1_relax          8          6         3        7        10
#  5       Video1_stress          2          3         3        1         0
#  6      Video1_valence        NaN          7         8        7         8
# ...

# %%
self_assessments.rename(columns = {'Tasks':'Subject'}, inplace = True)
self_assessments_transform = self_assessments.set_index('Subject').transpose()
self_assessments_transform
# Out:
# Subject Breathing_relax Breathing_stress Breathing_valence Breathing_arousal  \
# hh2e                  6                5               NaN               NaN
# wfsl                  6                4                 8                 3
# 37ir                  9                2                 5                 3
# hvpa                  9                1                 7                 8
# ql3b                 10                1                 5                 2
# ...                 ...              ...               ...               ...
# c3m7                  4                6                 8                 7
# b2l8                  8                1                 7                 8
# a1k9                  7                5                 6                 8
# t6v9                  5                5                 6                 3
# b9w0                  8                2                 7                 8
#
# ...
